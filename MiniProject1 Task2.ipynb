# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report #7c
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# Question 2 Loading the dataset
drugDataset = pd.read_csv("C:/Users/Gaith/Downloads/drug200.csv")

# Question 3
classes = ["DrugA", "DrugB", "DrugC", "DrugX", "DrugY"]
instances = [23, 16, 16, 54, 91]

plt.title('Distribution of the instances corresponding to our 5 classes')
plt.xlabel('Classes')
plt.ylabel('Number of instances')

myfig = plt.plot(classes, instances, 'bo')
plt.savefig("drug-distribution.pdf")
plt.show()
    
# Question 4    
#s = pd.Series(list)

# Question 5 Splitting    

Y = drugDataset.Drug
X = drugDataset.drop('Drug', axis = 1)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y)


#-----------------------------------
vectorizer = CountVectorizer()
matrix1 = vectorizer.fit_transform(X_train)

matrix2 = vectorizer.fit_transform(X_test)

Token1 = matrix1.toarray()
Token2 = matrix2.toarray()

#-----------------------------------

# Question 6

# Question 6 (a) Gaussian Naive Bayes
gausNB = GaussianNB()
gausNB.fit(matrix1, Y_train)

classPredictGauss = gausNB.predict(matrix2)

ConfusionMatrix = metrics.confusion_matrix(Y_test, classPredictGauss)
print('Confusion Matrix: ')
print(ConfusionMatrix, '\n')

target_namesGNB = ['drugA', 'drugB', 'drugC', 'drugX', 'drugY']
print('\n', 'Classification Report')
print(classification_report(Y_test, classPredictGuass, target_names=target_namesGNB))

guassAccuracy = metrics.accuracy_score(Y_test, classPredictGauss)
guassMacroF1score = f1_score(Y_test, classPredictGauss, average='macro')
guassWeightedF1score = f1_score(Y_test, classPredictGauss, average='weighted')

print('Accuracy = ', gaussAccuracy)
print('MacroF1score = ', gaussMacroF1score)
print('WeightedF1score = ', gaussWeightedF1score)

#---------------------------------------------------------------------------------------------------------------
# Question 6 (b) Base-DT
dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(matrix1, Y_train)
classPredictBaseDT = dtc.predict(matrix2)

ConfusionMatrix = metrics.confusion_matrix(Y_test, classPredictBaseDT)
print('Confusion Matrix: ')
print(ConfusionMatrix, '\n')

target_namesBDT = ['drugA', 'drugB', 'drugC', 'drugX', 'drugY']
print('\n', 'Classification Report')
print(classification_report(Y_test, classPredictGuass, target_names=target_namesBDT))

BaseDTAccuracy = metrics.accuracy_score(Y_test, classPredictBaseDT)
BaseDTMacroF1score = f1_score(Y_test, classPredictBaseDT, average='macro')
BaseDTWeightedF1score = f1_score(Y_test, classPredictBaseDT, average='weighted')

print('Accuracy = ', BaseDTAccuracy)
print('MacroF1score = ', BaseDTMacroF1score)
print('WeightedF1score = ', BaseDTWeightedF1score)

#---------------------------------------------------------------------------------------------------------------
# Question 6 (c) Top-DT
dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(matrix1, Y_train)
classPredictTopDT = dtc.predict(matrix2)

ConfusionMatrix = metrics.confusion_matrix(Y_test, classPredictTopDT)
print('Confusion Matrix: ')
print(ConfusionMatrix, '\n')

target_namesTopDT = ['drugA', 'drugB', 'drugC', 'drugX', 'drugY']
print('\n', 'Classification Report')
print(classification_report(Y_test, classPredictGuass, target_names=target_namesTopDT))

TopDTAccuracy = metrics.accuracy_score(Y_test, classPredictTopDT)
TopDTMacroF1score = f1_score(Y_test, classPredictTopDT, average='macro')
TopDTWeightedF1score = f1_score(Y_test, classPredictTopDT, average='weighted')

print('Accuracy = ', TopDTAccuracy)
print('MacroF1score = ', TopDTMacroF1score)
print('WeightedF1score = ', TopDTWeightedF1score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8212/556693315.py in <module>
#      53 # Question 6 (a) Gaussian Naive Bayes
#      54 gausNB = GaussianNB()
# ---> 55 gausNB.fit(matrix1, Y_train)
#      56
#      57 classPredictGauss = gausNB.predict(matrix2)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     242             Returns the instance itself.
#     243         """
# --> 244         X, y = self._validate_data(X, y)
#     245         return self._partial_fit(
#     246             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     570                 y = check_array(y, **check_y_params)
# ...

# %%
import pandas as pd
drugDataset = pd.read_csv("C:/Users/Gaith/Downloads/drug200.csv")

drugDataset
#print('-----------')

#drugDataset.
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]
